# %%
# tiny_shakespeare_fractal_rg_lm.py
import os
import math
import time
import requests
from dataclasses import dataclass
from typing import List, Tuple

import torch
import torch.nn as nn
import torch.nn.functional as F


# ================== 配置 ==================

@dataclass
class Config:
    data_url: str = "https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt"
    data_path: str = "input.txt"

    batch_size: int = 64
    block_size: int = 128  # 上下文长度
    max_iters: int = 20000
    eval_interval: int = 500
    eval_iters: int = 50

    n_layer: int = 4
    n_head: int = 4
    n_embd: int = 256
    d_ff: int = 1024

    lr: float = 3e-4
    dropout: float = 0.1

    use_fractal: bool = True   # 切换架构：True=分形RG注意力，False=普通Transformer


cfg = Config()
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device, " (FractalRG:", cfg.use_fractal, ")")


# ================== 数据加载：tiny-shakespeare ==================

def download_tiny_shakespeare(cfg: Config):
    if os.path.exists(cfg.data_path):
        print(f"Found {cfg.data_path}, skip download.")
        return
    print("Downloading tiny-shakespeare...")
    r = requests.get(cfg.data_url)
    r.raise_for_status()
    with open(cfg.data_path, "w", encoding="utf-8") as f:
        f.write(r.text)
    print("Download finished.")


download_tiny_shakespeare(cfg)

with open(cfg.data_path, "r", encoding="utf-8") as f:
    text = f.read()

print("Data length:", len(text))

# 字符级 vocab
chars = sorted(list(set(text)))
vocab_size = len(chars)
print("Vocab size:", vocab_size)

stoi = {ch: i for i, ch in enumerate(chars)}
itos = {i: ch for i, ch in enumerate(chars)}

def encode(s: str):
    return [stoi[c] for c in s]

def decode(ids):
    return "".join(itos[i] for i in ids)

# 整个语料编码为整数
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9 * len(data))
train_data = data[:n]
val_data = data[n:]


def get_batch(split: str, cfg: Config):
    """
    从 train/val 中随机采样一个 batch，形状 [B, T]
    """
    if split == "train":
        d = train_data
    else:
        d = val_data
    ix = torch.randint(len(d) - cfg.block_size - 1, (cfg.batch_size,))
    x = torch.stack([d[i : i + cfg.block_size] for i in ix])
    y = torch.stack([d[i + 1 : i + 1 + cfg.block_size] for i in ix])
    return x.to(device), y.to(device)


# ================== 一些 Attention 工具函数 ==================

def causal_mask(L: int, device: torch.device):
    """
    生成因果 mask：上三角为 True（要被屏蔽）
    """
    return torch.triu(torch.ones(L, L, device=device, dtype=torch.bool), diagonal=1)


def coarse_grain_1d(x: torch.Tensor) -> torch.Tensor:
    """
    x: [B, L, D] -> [B, L//2, D]
    简单 stride=2 平均池化 (RG coarse-grain)
    """
    B, L, D = x.shape
    if L % 2 != 0:
        x = x[:, :L - 1, :]
        L = L - 1
    x = x.view(B, L // 2, 2, D).mean(dim=2)
    return x


def upsample_to_length(x: torch.Tensor, target_len: int) -> torch.Tensor:
    """
    x: [B, Ls, D] -> [B, target_len, D] 线性插值上采样
    """
    B, Ls, D = x.shape
    if Ls == target_len:
        return x
    x_t = x.transpose(1, 2)  # [B,D,Ls]
    x_up = F.interpolate(x_t, size=target_len, mode="linear", align_corners=False)
    x_up = x_up.transpose(1, 2)  # [B,target_len,D]
    return x_up


# ================== Baseline: Causal Multihead Self-Attention ==================

class MultiHeadSelfAttentionCausal(nn.Module):
    def __init__(self, d_model: int, n_heads: int, dropout: float = 0.1):
        super().__init__()
        assert d_model % n_heads == 0
        self.d_model = d_model
        self.n_heads = n_heads
        self.head_dim = d_model // n_heads

        self.q_proj = nn.Linear(d_model, d_model)
        self.k_proj = nn.Linear(d_model, d_model)
        self.v_proj = nn.Linear(d_model, d_model)
        self.o_proj = nn.Linear(d_model, d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x: torch.Tensor):
        """
        x: [B, T, D]
        """
        B, T, D = x.shape
        H = self.n_heads
        d_h = self.head_dim

        q = self.q_proj(x)
        k = self.k_proj(x)
        v = self.v_proj(x)

        def split(t):
            return t.view(B, T, H, d_h).transpose(1, 2)  # [B,H,T,d_h]

        q = split(q)
        k = split(k)
        v = split(v)

        scores = torch.matmul(q, k.transpose(-2, -1)) / math.sqrt(d_h)  # [B,H,T,T]

        # 因果 mask
        mask = causal_mask(T, x.device)  # [T,T]
        scores = scores.masked_fill(mask.view(1, 1, T, T), float("-inf"))

        attn = F.softmax(scores, dim=-1)
        attn = self.dropout(attn)

        out = torch.matmul(attn, v)  # [B,H,T,d_h]
        out = out.transpose(1, 2).contiguous().view(B, T, D)  # [B,T,D]
        out = self.o_proj(out)
        return out


class VanillaBlock(nn.Module):
    def __init__(self, d_model: int, n_heads: int, d_ff: int, dropout: float = 0.1):
        super().__init__()
        self.ln1 = nn.LayerNorm(d_model)
        self.attn = MultiHeadSelfAttentionCausal(d_model, n_heads, dropout)
        self.ln2 = nn.LayerNorm(d_model)
        self.ff = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.GELU(),
            nn.Linear(d_ff, d_model),
            nn.Dropout(dropout),
        )

    def forward(self, x: torch.Tensor):
        h = self.ln1(x)
        h = self.attn(h)
        x = x + h

        h2 = self.ln2(x)
        h2 = self.ff(h2)
        x = x + h2
        return x, None  # 为了和 FractalRG 接口统一，返回第二项占位


# ================== Fractal-RG Multi-Scale Attention ==================

class FractalRGAttention(nn.Module):
    """
    因果、多头、多尺度距离衰减注意力：
    - 不做下采样 / 上采样，不改变序列长度；
    - 每个 head 有自己的可学习尺度 R_h；
    - logits_{h,ij} = qk / sqrt(d) - lambda_dist * |i-j| / R_h；
    - 加 causal mask 保证只能看过去。
    """
    def __init__(
        self,
        d_model: int,
        n_heads: int,
        num_scales: int = 1,      # 为兼容原调用，保留这个参数
        base_radius: float = 16.0,
        lambda_dist: float = 1.0,
        dropout_p: float = 0.1,
    ):
        super().__init__()
        assert d_model % n_heads == 0
        self.d_model = d_model
        self.n_heads = n_heads
        self.head_dim = d_model // n_heads
        self.base_radius = base_radius
        self.lambda_dist = lambda_dist

        # 共享 QKV 投影
        self.q_proj = nn.Linear(d_model, d_model)
        self.k_proj = nn.Linear(d_model, d_model)
        self.v_proj = nn.Linear(d_model, d_model)
        self.out_proj = nn.Linear(d_model, d_model)

        self.attn_dropout = nn.Dropout(dropout_p)

        # 每个 head 一个 log_R_h，可学习
        # R_h = base_radius * exp(log_R_h[h])
        self.log_R = nn.Parameter(torch.zeros(n_heads))

    def forward(self, x: torch.Tensor):
        """
        x: [B, T, D]
        返回:
          out: [B, T, D]
          attn_list: [attn] 其中 attn: [B, H, T, T]
        """
        B, T, D = x.shape
        H = self.n_heads
        d_h = self.head_dim

        # Q,K,V
        q = self.q_proj(x)  # [B,T,D]
        k = self.k_proj(x)
        v = self.v_proj(x)

        def split_heads(t):
            # [B,T,D] -> [B,H,T,d_h]
            return t.view(B, T, H, d_h).transpose(1, 2)

        q = split_heads(q)
        k = split_heads(k)
        v = split_heads(v)

        # 点积注意力 scores: [B,H,T,T]
        scores = torch.matmul(q, k.transpose(-2, -1)) / math.sqrt(d_h)

        # 距离矩阵 |i-j|: [T,T]
        idx = torch.arange(T, device=x.device)
        dist = (idx[:, None] - idx[None, :]).abs().float()  # [T,T]

        # 每个 head 的半径 R_h: [H]
        R_h = self.base_radius * torch.exp(self.log_R)      # [H]
        # reshape 方便广播: [1,H,1,1]
        R_h_broadcast = R_h.view(1, H, 1, 1)

        # 距离惩罚：scores_{h,ij} -= lambda * |i-j| / R_h
        scores = scores - self.lambda_dist * dist.view(1, 1, T, T) / (R_h_broadcast + 1e-6)

        # 因果 mask：只能看过去
        mask = torch.triu(torch.ones(T, T, device=x.device, dtype=torch.bool), diagonal=1)
        scores = scores.masked_fill(mask.view(1, 1, T, T), float("-inf"))

        # softmax + dropout
        attn = F.softmax(scores, dim=-1)
        attn = self.attn_dropout(attn)

        # [B,H,T,T] @ [B,H,T,d_h] -> [B,H,T,d_h]
        out = torch.matmul(attn, v)
        out = out.transpose(1, 2).contiguous().view(B, T, D)  # [B,T,D]
        out = self.out_proj(out)

        # 为了兼容原来 all_attn.append(attn_scales) 的用法，这里返回 [attn]
        return out, [attn]



class FractalRGBlock(nn.Module):
    def __init__(
        self,
        d_model: int,
        n_heads: int,
        d_ff: int,
        num_scales: int = 1,      # 为兼容原调用，保留这个参数
        base_radius: float = 16.0,
        lambda_dist: float = 1.0,
        attn_dropout: float = 0.1,
        ff_dropout: float = 0.1,
    ):
        super().__init__()
        self.ln1 = nn.LayerNorm(d_model)
        self.attn = FractalRGAttention(
            d_model=d_model,
            n_heads=n_heads,
            num_scales=num_scales,
            base_radius=base_radius,
            lambda_dist=lambda_dist,
            dropout_p=attn_dropout,
        )
        self.ln2 = nn.LayerNorm(d_model)
        self.ff = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.GELU(),
            nn.Linear(d_ff, d_model),
            nn.Dropout(ff_dropout),
        )

    def forward(self, x: torch.Tensor):
        # 注意力子层
        h = self.ln1(x)
        h_attn, attn_list = self.attn(h)
        x = x + h_attn

        # FFN 子层
        h2 = self.ln2(x)
        h2 = self.ff(h2)
        x = x + h2
        return x, attn_list  # attn_list: [attn]，和原脚本中的 all_attn 兼容



# ================== 语言模型封装 ==================

class FractalRGTransformerLM(nn.Module):
    def __init__(self, cfg: Config, vocab_size: int):
        super().__init__()
        self.cfg = cfg
        self.token_emb = nn.Embedding(vocab_size, cfg.n_embd)
        self.pos_emb = nn.Parameter(torch.zeros(1, cfg.block_size, cfg.n_embd))

        blocks = []
        for layer_idx in range(cfg.n_layer):
            if cfg.use_fractal:
                # 粗略设置一个 base_radius，让浅层更局部、深层更全局（可以随意改）
                base_R = cfg.block_size / (2 ** (layer_idx // 2 + 1))
                block = FractalRGBlock(
                    d_model=cfg.n_embd,
                    n_heads=cfg.n_head,
                    d_ff=cfg.d_ff,
                    num_scales=2,
                    base_radius=base_R,
                    lambda_dist=1.0,
                    attn_dropout=cfg.dropout,
                    ff_dropout=cfg.dropout,
                )
            else:
                block = VanillaBlock(
                    d_model=cfg.n_embd,
                    n_heads=cfg.n_head,
                    d_ff=cfg.d_ff,
                    dropout=cfg.dropout,
                )
            blocks.append(block)
        self.blocks = nn.ModuleList(blocks)
        self.ln_f = nn.LayerNorm(cfg.n_embd)
        self.lm_head = nn.Linear(cfg.n_embd, vocab_size)

    def forward(self, idx: torch.Tensor, targets: torch.Tensor | None = None):
        B, T = idx.shape
        assert T <= self.cfg.block_size

        tok_emb = self.token_emb(idx)                    # [B,T,C]
        pos_emb = self.pos_emb[:, :T, :]                 # [1,T,C]
        x = tok_emb + pos_emb                            # [B,T,C]

        all_attn = []
        for block in self.blocks:
            x, attn_scales = block(x)
            all_attn.append(attn_scales)

        x = self.ln_f(x)
        logits = self.lm_head(x)                         # [B,T,V]

        loss = None
        if targets is not None:
            B, T, V = logits.shape
            loss = F.cross_entropy(
                logits.view(B * T, V),
                targets.view(B * T),
            )

        return logits, loss, all_attn


# ================== 训练 / 评估 ==================

@torch.no_grad()
def estimate_loss(model: nn.Module, cfg: Config):
    model.eval()
    out = {}
    for split in ["train", "val"]:
        losses = []
        for _ in range(cfg.eval_iters):
            xb, yb = get_batch(split, cfg)
            _, loss, _ = model(xb, yb)
            losses.append(loss.item())
        out[split] = sum(losses) / len(losses)
    model.train()
    return out


def main(cfg: Config):
    model = FractalRGTransformerLM(cfg, vocab_size).to(device)
    print("Model parameters:", sum(p.numel() for p in model.parameters()) / 1e6, "M")

    optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.lr)

    for iter in range(cfg.max_iters):
        # 周期性评估
        if iter % cfg.eval_interval == 0:
            t0 = time.time()
            losses = estimate_loss(model, cfg)
            dt = time.time() - t0
            print(
                f"step {iter}: train loss {losses['train']:.4f}, "
                f"val loss {losses['val']:.4f} (eval {dt:.1f}s)"
            )

        xb, yb = get_batch("train", cfg)
        _, loss, _ = model(xb, yb)

        optimizer.zero_grad(set_to_none=True)
        loss.backward()
        optimizer.step()

        if (iter + 1) % 100 == 0:
            print(f"iter {iter+1}, train loss {loss.item():.4f}")

    # 训练结束后保存模型
    ckpt_name = "fractal_rg_lm.pt" if cfg.use_fractal else "vanilla_lm.pt"
    torch.save(model.state_dict(), ckpt_name)
    print("Saved model to", ckpt_name)


if __name__ == "__main__":
    main(cfg)
# Out:
# Using device: cuda  (FractalRG: True )
# Found input.txt, skip download.
# Data length: 1115394
# Vocab size: 65
# Model parameters: 3.225681 M
# step 0: train loss 4.3167, val loss 4.3171 (eval 10.5s)
# iter 100, train loss 2.4267
# iter 200, train loss 2.3366
# iter 300, train loss 2.2545
# iter 400, train loss 2.1598
# iter 500, train loss 2.1300
# step 500: train loss 2.0630, val loss 2.1490 (eval 4.8s)
# iter 600, train loss 2.0386
# iter 700, train loss 1.8763
# iter 800, train loss 1.8665
# iter 900, train loss 1.7962
# iter 1000, train loss 1.7907
# step 1000: train loss 1.6669, val loss 1.8270 (eval 4.8s)
# iter 1100, train loss 1.7019
# iter 1200, train loss 1.6610
# iter 1300, train loss 1.6496
# iter 1400, train loss 1.5791
# iter 1500, train loss 1.6068
# step 1500: train loss 1.5278, val loss 1.7070 (eval 4.8s)
# iter 1600, train loss 1.5660
# iter 1700, train loss 1.5841
# iter 1800, train loss 1.5246
# iter 1900, train loss 1.4994
# iter 2000, train loss 1.4929
# step 2000: train loss 1.4369, val loss 1.6348 (eval 4.8s)
# iter 2100, train loss 1.5123
# iter 2200, train loss 1.5019
# iter 2300, train loss 1.5233
# iter 2400, train loss 1.4721
# iter 2500, train loss 1.4090
# step 2500: train loss 1.3816, val loss 1.6044 (eval 4.8s)
# iter 2600, train loss 1.4225
# iter 2700, train loss 1.4056
# iter 2800, train loss 1.4162
# iter 2900, train loss 1.4302
# iter 3000, train loss 1.3495
# step 3000: train loss 1.3422, val loss 1.5867 (eval 4.8s)
# iter 3100, train loss 1.3776
# iter 3200, train loss 1.3894
# iter 3300, train loss 1.3785
# iter 3400, train loss 1.3360
# iter 3500, train loss 1.3734
# step 3500: train loss 1.3084, val loss 1.5780 (eval 4.8s)
# iter 3600, train loss 1.3903
# iter 3700, train loss 1.3653
# iter 3800, train loss 1.3552
# iter 3900, train loss 1.3385
# iter 4000, train loss 1.3342
# step 4000: train loss 1.2807, val loss 1.5530 (eval 4.8s)
# iter 4100, train loss 1.3337
# iter 4200, train loss 1.3191
# iter 4300, train loss 1.3629
# iter 4400, train loss 1.2568
# iter 4500, train loss 1.3041
# step 4500: train loss 1.2514, val loss 1.5470 (eval 4.8s)
# iter 4600, train loss 1.3200
# iter 4700, train loss 1.2654
# iter 4800, train loss 1.3078
# iter 4900, train loss 1.3058
# iter 5000, train loss 1.2996
# step 5000: train loss 1.2288, val loss 1.5449 (eval 4.8s)
# iter 5100, train loss 1.3004
# iter 5200, train loss 1.2743
# iter 5300, train loss 1.2715
# iter 5400, train loss 1.2748
# iter 5500, train loss 1.2648
# step 5500: train loss 1.1943, val loss 1.5544 (eval 4.8s)
# iter 5600, train loss 1.2553
# iter 5700, train loss 1.2503
# iter 5800, train loss 1.2381
# iter 5900, train loss 1.2628
# iter 6000, train loss 1.2331
# step 6000: train loss 1.1770, val loss 1.5375 (eval 4.8s)
# iter 6100, train loss 1.2077
# iter 6200, train loss 1.2429
# iter 6300, train loss 1.2419
# iter 6400, train loss 1.1976
# iter 6500, train loss 1.2460
# step 6500: train loss 1.1595, val loss 1.5653 (eval 4.8s)
# iter 6600, train loss 1.2263
# iter 6700, train loss 1.2178
# iter 6800, train loss 1.1861
# iter 6900, train loss 1.1926
# iter 7000, train loss 1.2008
# step 7000: train loss 1.1318, val loss 1.5639 (eval 4.8s)
# iter 7100, train loss 1.1697
# iter 7200, train loss 1.2074
# iter 7300, train loss 1.1881
# iter 7400, train loss 1.1916
# iter 7500, train loss 1.1784
# step 7500: train loss 1.1128, val loss 1.5721 (eval 4.8s)
# iter 7600, train loss 1.1756
# iter 7700, train loss 1.1856
# iter 7800, train loss 1.1765
# iter 7900, train loss 1.1458
# iter 8000, train loss 1.1287
# step 8000: train loss 1.0860, val loss 1.5652 (eval 4.8s)
# iter 8100, train loss 1.1547
# iter 8200, train loss 1.1588
# iter 8300, train loss 1.1557
# iter 8400, train loss 1.1404
# iter 8500, train loss 1.1538
# step 8500: train loss 1.0659, val loss 1.5886 (eval 4.6s)
# iter 8600, train loss 1.1418
# iter 8700, train loss 1.1327
# iter 8800, train loss 1.1374
# iter 8900, train loss 1.1437
# iter 9000, train loss 1.0953
# step 9000: train loss 1.0404, val loss 1.6079 (eval 4.7s)
# iter 9100, train loss 1.1355
# iter 9200, train loss 1.1280
# iter 9300, train loss 1.1508
# iter 9400, train loss 1.0934
# iter 9500, train loss 1.0923
# step 9500: train loss 1.0164, val loss 1.6179 (eval 4.8s)
# iter 9600, train loss 1.1270
# iter 9700, train loss 1.0907
# iter 9800, train loss 1.1355
# iter 9900, train loss 1.1173
# iter 10000, train loss 1.0967
# step 10000: train loss 0.9974, val loss 1.6289 (eval 4.8s)
# iter 10100, train loss 1.0557
# iter 10200, train loss 1.0944
# iter 10300, train loss 1.0916
# iter 10400, train loss 1.0612
# iter 10500, train loss 1.0399
# step 10500: train loss 0.9712, val loss 1.6555 (eval 4.8s)
# iter 10600, train loss 1.0742
# iter 10700, train loss 1.0883
# iter 10800, train loss 1.0439
# iter 10900, train loss 1.0455
# iter 11000, train loss 1.0629
# step 11000: train loss 0.9452, val loss 1.6681 (eval 4.8s)
# iter 11100, train loss 1.0554
# iter 11200, train loss 1.0485
# iter 11300, train loss 1.0688
# iter 11400, train loss 1.0285
# iter 11500, train loss 1.0403
# step 11500: train loss 0.9289, val loss 1.6721 (eval 4.8s)
# iter 11600, train loss 1.0834
# iter 11700, train loss 1.0535
# iter 11800, train loss 1.0246
# iter 11900, train loss 1.0326
# iter 12000, train loss 1.0392
# step 12000: train loss 0.9063, val loss 1.6965 (eval 4.9s)
# iter 12100, train loss 1.0314
# iter 12200, train loss 1.0513
# iter 12300, train loss 0.9968
# iter 12400, train loss 1.0159
# iter 12500, train loss 1.0060
# step 12500: train loss 0.8825, val loss 1.7389 (eval 4.8s)
# iter 12600, train loss 1.0468
# iter 12700, train loss 0.9966
# iter 12800, train loss 0.9880
# iter 12900, train loss 1.0275
# iter 13000, train loss 0.9680
# step 13000: train loss 0.8596, val loss 1.7628 (eval 4.8s)
# iter 13100, train loss 0.9912
# iter 13200, train loss 0.9712
# iter 13300, train loss 0.9992
# iter 13400, train loss 1.0214
# iter 13500, train loss 0.9429
# step 13500: train loss 0.8367, val loss 1.7669 (eval 4.8s)
# iter 13600, train loss 0.9809
# iter 13700, train loss 0.9965
# iter 13800, train loss 0.9754
# iter 13900, train loss 0.9507
# iter 14000, train loss 0.9575
# step 14000: train loss 0.8136, val loss 1.7782 (eval 4.8s)
# iter 14100, train loss 0.9758
# iter 14200, train loss 1.0002
# iter 14300, train loss 0.9569
# iter 14400, train loss 0.9787
# iter 14500, train loss 0.9639
# step 14500: train loss 0.7943, val loss 1.8057 (eval 4.8s)
# iter 14600, train loss 0.9532
# iter 14700, train loss 0.9359
# iter 14800, train loss 0.9224
# iter 14900, train loss 0.9325
# iter 15000, train loss 0.9396
# step 15000: train loss 0.7748, val loss 1.8362 (eval 4.8s)
# iter 15100, train loss 0.9285
# iter 15200, train loss 0.9548
# iter 15300, train loss 0.9136
# iter 15400, train loss 0.9173
# iter 15500, train loss 0.9367
# step 15500: train loss 0.7549, val loss 1.8464 (eval 4.8s)
# iter 15600, train loss 0.9072
# iter 15700, train loss 0.8954
# iter 15800, train loss 0.8852
# iter 15900, train loss 0.9076
# iter 16000, train loss 0.8994
# step 16000: train loss 0.7407, val loss 1.8740 (eval 4.8s)
# iter 16100, train loss 0.9012
# iter 16200, train loss 0.8902
# iter 16300, train loss 0.8969
# iter 16400, train loss 0.8799
# iter 16500, train loss 0.8845
# step 16500: train loss 0.7192, val loss 1.8847 (eval 4.8s)
# iter 16600, train loss 0.8996
# iter 16700, train loss 0.8942
# iter 16800, train loss 0.9080
# iter 16900, train loss 0.8955
# iter 17000, train loss 0.8581
# step 17000: train loss 0.7028, val loss 1.9091 (eval 4.8s)
# iter 17100, train loss 0.8619
# iter 17200, train loss 0.8986
# iter 17300, train loss 0.8740
# iter 17400, train loss 0.8714
# iter 17500, train loss 0.8538
# step 17500: train loss 0.6843, val loss 1.9215 (eval 4.8s)
# iter 17600, train loss 0.8484
# iter 17700, train loss 0.8705
# iter 17800, train loss 0.8403
# iter 17900, train loss 0.8799
# iter 18000, train loss 0.8565
# step 18000: train loss 0.6708, val loss 1.9473 (eval 4.8s)
# iter 18100, train loss 0.8528
# iter 18200, train loss 0.8836
# iter 18300, train loss 0.8689
# iter 18400, train loss 0.8566
# iter 18500, train loss 0.8181
# step 18500: train loss 0.6508, val loss 1.9609 (eval 4.8s)
# iter 18600, train loss 0.8584
# iter 18700, train loss 0.8147
# iter 18800, train loss 0.8230
# iter 18900, train loss 0.7958
# iter 19000, train loss 0.8325
# step 19000: train loss 0.6373, val loss 2.0036 (eval 4.8s)
# iter 19100, train loss 0.7788
# iter 19200, train loss 0.7965
# iter 19300, train loss 0.8256
# iter 19400, train loss 0.8363
# iter 19500, train loss 0.8374
# step 19500: train loss 0.6228, val loss 1.9998 (eval 4.8s)
# iter 19600, train loss 0.8106
# iter 19700, train loss 0.8163
# iter 19800, train loss 0.8145
# iter 19900, train loss 0.8273
# iter 20000, train loss 0.7856
# Saved model to fractal_rg_lm.pt

# %%
# tiny_shakespeare_fractal_rg_lm.py
import os
import math
import time
import requests
from dataclasses import dataclass
from typing import List, Tuple

import torch
import torch.nn as nn
import torch.nn.functional as F


# ================== 配置 ==================

@dataclass
class Config:
    data_url: str = "https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt"
    data_path: str = "input.txt"

    batch_size: int = 64
    block_size: int = 128  # 上下文长度
    max_iters: int = 20000
    eval_interval: int = 500
    eval_iters: int = 50

    n_layer: int = 4
    n_head: int = 4
    n_embd: int = 256
    d_ff: int = 1024

    lr: float = 3e-4
    dropout: float = 0.1

    use_fractal: bool = False   # 切换架构：True=分形RG注意力，False=普通Transformer


cfg = Config()
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device, " (FractalRG:", cfg.use_fractal, ")")


# ================== 数据加载：tiny-shakespeare ==================

def download_tiny_shakespeare(cfg: Config):
    if os.path.exists(cfg.data_path):
        print(f"Found {cfg.data_path}, skip download.")
        return
    print("Downloading tiny-shakespeare...")
    r = requests.get(cfg.data_url)
    r.raise_for_status()
    with open(cfg.data_path, "w", encoding="utf-8") as f:
        f.write(r.text)
    print("Download finished.")


download_tiny_shakespeare(cfg)

with open(cfg.data_path, "r", encoding="utf-8") as f:
    text = f.read()

print("Data length:", len(text))

# 字符级 vocab
chars = sorted(list(set(text)))
vocab_size = len(chars)
print("Vocab size:", vocab_size)

stoi = {ch: i for i, ch in enumerate(chars)}
itos = {i: ch for i, ch in enumerate(chars)}

def encode(s: str):
    return [stoi[c] for c in s]

def decode(ids):
    return "".join(itos[i] for i in ids)

# 整个语料编码为整数
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9 * len(data))
train_data = data[:n]
val_data = data[n:]


def get_batch(split: str, cfg: Config):
    """
    从 train/val 中随机采样一个 batch，形状 [B, T]
    """
    if split == "train":
        d = train_data
    else:
        d = val_data
    ix = torch.randint(len(d) - cfg.block_size - 1, (cfg.batch_size,))
    x = torch.stack([d[i : i + cfg.block_size] for i in ix])
    y = torch.stack([d[i + 1 : i + 1 + cfg.block_size] for i in ix])
    return x.to(device), y.to(device)


# ================== 一些 Attention 工具函数 ==================

def causal_mask(L: int, device: torch.device):
    """
    生成因果 mask：上三角为 True（要被屏蔽）
    """
    return torch.triu(torch.ones(L, L, device=device, dtype=torch.bool), diagonal=1)


def coarse_grain_1d(x: torch.Tensor) -> torch.Tensor:
    """
    x: [B, L, D] -> [B, L//2, D]
    简单 stride=2 平均池化 (RG coarse-grain)
    """
    B, L, D = x.shape
    if L % 2 != 0:
        x = x[:, :L - 1, :]
        L = L - 1
    x = x.view(B, L // 2, 2, D).mean(dim=2)
    return x


def upsample_to_length(x: torch.Tensor, target_len: int) -> torch.Tensor:
    """
    x: [B, Ls, D] -> [B, target_len, D] 线性插值上采样
    """
    B, Ls, D = x.shape
    if Ls == target_len:
        return x
    x_t = x.transpose(1, 2)  # [B,D,Ls]
    x_up = F.interpolate(x_t, size=target_len, mode="linear", align_corners=False)
    x_up = x_up.transpose(1, 2)  # [B,target_len,D]
    return x_up


# ================== Baseline: Causal Multihead Self-Attention ==================

class MultiHeadSelfAttentionCausal(nn.Module):
    def __init__(self, d_model: int, n_heads: int, dropout: float = 0.1):
        super().__init__()
        assert d_model % n_heads == 0
        self.d_model = d_model
        self.n_heads = n_heads
        self.head_dim = d_model // n_heads

        self.q_proj = nn.Linear(d_model, d_model)
        self.k_proj = nn.Linear(d_model, d_model)
        self.v_proj = nn.Linear(d_model, d_model)
        self.o_proj = nn.Linear(d_model, d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x: torch.Tensor):
        """
        x: [B, T, D]
        """
        B, T, D = x.shape
        H = self.n_heads
        d_h = self.head_dim

        q = self.q_proj(x)
        k = self.k_proj(x)
        v = self.v_proj(x)

        def split(t):
            return t.view(B, T, H, d_h).transpose(1, 2)  # [B,H,T,d_h]

        q = split(q)
        k = split(k)
        v = split(v)

        scores = torch.matmul(q, k.transpose(-2, -1)) / math.sqrt(d_h)  # [B,H,T,T]

        # 因果 mask
        mask = causal_mask(T, x.device)  # [T,T]
        scores = scores.masked_fill(mask.view(1, 1, T, T), float("-inf"))

        attn = F.softmax(scores, dim=-1)
        attn = self.dropout(attn)

        out = torch.matmul(attn, v)  # [B,H,T,d_h]
        out = out.transpose(1, 2).contiguous().view(B, T, D)  # [B,T,D]
        out = self.o_proj(out)
        return out


class VanillaBlock(nn.Module):
    def __init__(self, d_model: int, n_heads: int, d_ff: int, dropout: float = 0.1):
        super().__init__()
        self.ln1 = nn.LayerNorm(d_model)
        self.attn = MultiHeadSelfAttentionCausal(d_model, n_heads, dropout)
        self.ln2 = nn.LayerNorm(d_model)
        self.ff = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.GELU(),
            nn.Linear(d_ff, d_model),
            nn.Dropout(dropout),
        )

    def forward(self, x: torch.Tensor):
        h = self.ln1(x)
        h = self.attn(h)
        x = x + h

        h2 = self.ln2(x)
        h2 = self.ff(h2)
        x = x + h2
        return x, None  # 为了和 FractalRG 接口统一，返回第二项占位


# ================== Fractal-RG Multi-Scale Attention ==================

class FractalRGAttention(nn.Module):
    def __init__(
        self,
        d_model: int,
        n_heads: int,
        num_scales: int = 2,
        base_radius: float = 16.0,
        lambda_dist: float = 1.0,
        dropout_p: float = 0.1,
    ):
        super().__init__()
        assert d_model % n_heads == 0
        self.d_model = d_model
        self.n_heads = n_heads
        self.head_dim = d_model // n_heads
        self.num_scales = num_scales
        self.base_radius = base_radius
        self.lambda_dist = lambda_dist

        self.q_proj = nn.Linear(d_model, d_model)
        self.k_proj = nn.Linear(d_model, d_model)
        self.v_proj = nn.Linear(d_model, d_model)
        self.out_proj = nn.Linear(d_model, d_model)
        self.attn_dropout = nn.Dropout(dropout_p)

        # 尺度参数 log_R_s，可学习
        self.log_R = nn.Parameter(torch.zeros(num_scales))
        # 多尺度融合权重（softmax 后为 g_s）
        self.scale_logits = nn.Parameter(torch.zeros(num_scales))

    def _scaled_dot_attn(
        self,
        x: torch.Tensor,
        R_s: float,
    ) -> Tuple[torch.Tensor, torch.Tensor]:
        """
        在单个尺度上计算 causal self-attention
        x: [B, Ls, D]
        """
        B, Ls, D = x.shape
        H = self.n_heads
        d_h = self.head_dim

        q = self.q_proj(x)
        k = self.k_proj(x)
        v = self.v_proj(x)

        def split(t):
            return t.view(B, Ls, H, d_h).transpose(1, 2)  # [B,H,Ls,d_h]

        q = split(q)
        k = split(k)
        v = split(v)

        scores = torch.matmul(q, k.transpose(-2, -1)) / math.sqrt(d_h)  # [B,H,Ls,Ls]

        # 距离惩罚项
        idx = torch.arange(Ls, device=x.device)
        dist = (idx[:, None] - idx[None, :]).abs().float()  # [Ls,Ls]
        scores = scores - self.lambda_dist * dist / (R_s + 1e-6)

        # 因果 mask
        mask = causal_mask(Ls, x.device)  # [Ls,Ls]
        scores = scores.masked_fill(mask.view(1, 1, Ls, Ls), float("-inf"))

        attn = F.softmax(scores, dim=-1)
        attn = self.attn_dropout(attn)

        h = torch.matmul(attn, v)  # [B,H,Ls,d_h]
        h = h.transpose(1, 2).contiguous().view(B, Ls, D)  # [B,Ls,D]
        return h, attn

    def forward(self, x: torch.Tensor):
        """
        x: [B, L, D]
        返回:
          out: [B, L, D]
          attn_scales: List[[B,H,Ls,Ls]]
        """
        B, L, D = x.shape

        # 构造多尺度表示
        xs: List[torch.Tensor] = [x]
        for _ in range(1, self.num_scales):
            xs.append(coarse_grain_1d(xs[-1]))

        scale_weights = F.softmax(self.scale_logits, dim=-1)  # g_s
        out = torch.zeros_like(x)
        attn_scales: List[torch.Tensor] = []

        for s, x_s in enumerate(xs):
            R_s = self.base_radius * torch.exp(self.log_R[s])  # 标量
            h_s, attn_s = self._scaled_dot_attn(x_s, R_s)
            attn_scales.append(attn_s)

            # 上采样回原长度并加权融合
            h_up = upsample_to_length(h_s, L)
            out = out + scale_weights[s] * h_up

        out = self.out_proj(out)
        return out, attn_scales


class FractalRGBlock(nn.Module):
    def __init__(
        self,
        d_model: int,
        n_heads: int,
        d_ff: int,
        num_scales: int = 2,
        base_radius: float = 16.0,
        lambda_dist: float = 1.0,
        attn_dropout: float = 0.1,
        ff_dropout: float = 0.1,
    ):
        super().__init__()
        self.ln1 = nn.LayerNorm(d_model)
        self.attn = FractalRGAttention(
            d_model=d_model,
            n_heads=n_heads,
            num_scales=num_scales,
            base_radius=base_radius,
            lambda_dist=lambda_dist,
            dropout_p=attn_dropout,
        )
        self.ln2 = nn.LayerNorm(d_model)
        self.ff = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.GELU(),
            nn.Linear(d_ff, d_model),
            nn.Dropout(ff_dropout),
        )

    def forward(self, x: torch.Tensor):
        h = self.ln1(x)
        h_attn, attn_scales = self.attn(h)
        x = x + h_attn

        h2 = self.ln2(x)
        h2 = self.ff(h2)
        x = x + h2
        return x, attn_scales


# ================== 语言模型封装 ==================

class FractalRGTransformerLM(nn.Module):
    def __init__(self, cfg: Config, vocab_size: int):
        super().__init__()
        self.cfg = cfg
        self.token_emb = nn.Embedding(vocab_size, cfg.n_embd)
        self.pos_emb = nn.Parameter(torch.zeros(1, cfg.block_size, cfg.n_embd))

        blocks = []
        for layer_idx in range(cfg.n_layer):
            if cfg.use_fractal:
                # 粗略设置一个 base_radius，让浅层更局部、深层更全局（可以随意改）
                base_R = cfg.block_size / (2 ** (layer_idx // 2 + 1))
                block = FractalRGBlock(
                    d_model=cfg.n_embd,
                    n_heads=cfg.n_head,
                    d_ff=cfg.d_ff,
                    num_scales=2,
                    base_radius=base_R,
                    lambda_dist=1.0,
                    attn_dropout=cfg.dropout,
                    ff_dropout=cfg.dropout,
                )
            else:
                block = VanillaBlock(
                    d_model=cfg.n_embd,
                    n_heads=cfg.n_head,
                    d_ff=cfg.d_ff,
                    dropout=cfg.dropout,
                )
            blocks.append(block)
        self.blocks = nn.ModuleList(blocks)
        self.ln_f = nn.LayerNorm(cfg.n_embd)
        self.lm_head = nn.Linear(cfg.n_embd, vocab_size)

    def forward(self, idx: torch.Tensor, targets: torch.Tensor | None = None):
        B, T = idx.shape
        assert T <= self.cfg.block_size

        tok_emb = self.token_emb(idx)                    # [B,T,C]
        pos_emb = self.pos_emb[:, :T, :]                 # [1,T,C]
        x = tok_emb + pos_emb                            # [B,T,C]

        all_attn = []
        for block in self.blocks:
            x, attn_scales = block(x)
            all_attn.append(attn_scales)

        x = self.ln_f(x)
        logits = self.lm_head(x)                         # [B,T,V]

        loss = None
        if targets is not None:
            B, T, V = logits.shape
            loss = F.cross_entropy(
                logits.view(B * T, V),
                targets.view(B * T),
            )

        return logits, loss, all_attn


# ================== 训练 / 评估 ==================

@torch.no_grad()
def estimate_loss(model: nn.Module, cfg: Config):
    model.eval()
    out = {}
    for split in ["train", "val"]:
        losses = []
        for _ in range(cfg.eval_iters):
            xb, yb = get_batch(split, cfg)
            _, loss, _ = model(xb, yb)
            losses.append(loss.item())
        out[split] = sum(losses) / len(losses)
    model.train()
    return out


def main(cfg: Config):
    model = FractalRGTransformerLM(cfg, vocab_size).to(device)
    print("Model parameters:", sum(p.numel() for p in model.parameters()) / 1e6, "M")

    optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.lr)

    for iter in range(cfg.max_iters):
        # 周期性评估
        if iter % cfg.eval_interval == 0:
            t0 = time.time()
            losses = estimate_loss(model, cfg)
            dt = time.time() - t0
            print(
                f"step {iter}: train loss {losses['train']:.4f}, "
                f"val loss {losses['val']:.4f} (eval {dt:.1f}s)"
            )

        xb, yb = get_batch("train", cfg)
        _, loss, _ = model(xb, yb)

        optimizer.zero_grad(set_to_none=True)
        loss.backward()
        optimizer.step()

        if (iter + 1) % 100 == 0:
            print(f"iter {iter+1}, train loss {loss.item():.4f}")

    # 训练结束后保存模型
    ckpt_name = "fractal_rg_lm.pt" if cfg.use_fractal else "vanilla_lm.pt"
    torch.save(model.state_dict(), ckpt_name)
    print("Saved model to", ckpt_name)


if __name__ == "__main__":
    main(cfg)
# Out:
# Using device: cuda  (FractalRG: False )
# Found input.txt, skip download.
# Data length: 1115394
# Vocab size: 65
# Model parameters: 3.225665 M
# step 0: train loss 4.4069, val loss 4.4038 (eval 4.7s)
# iter 100, train loss 2.4556
# iter 200, train loss 2.3880
# iter 300, train loss 2.3867
# iter 400, train loss 2.3386
# iter 500, train loss 2.2266
# step 500: train loss 2.2075, val loss 2.2900 (eval 4.7s)
# iter 600, train loss 2.0654
# iter 700, train loss 1.9703
# iter 800, train loss 1.9031
# iter 900, train loss 1.8170
# iter 1000, train loss 1.7880
# step 1000: train loss 1.7059, val loss 1.8506 (eval 4.7s)
# iter 1100, train loss 1.7424
# iter 1200, train loss 1.7094
# iter 1300, train loss 1.6904
# iter 1400, train loss 1.6049
# iter 1500, train loss 1.6468
# step 1500: train loss 1.5313, val loss 1.7219 (eval 4.7s)
# iter 1600, train loss 1.5886
# iter 1700, train loss 1.5505
# iter 1800, train loss 1.5407
# iter 1900, train loss 1.5547
# iter 2000, train loss 1.4825
# step 2000: train loss 1.4502, val loss 1.6499 (eval 4.7s)
# iter 2100, train loss 1.5315
# iter 2200, train loss 1.4729
# iter 2300, train loss 1.4790
# iter 2400, train loss 1.4444
# iter 2500, train loss 1.4485
# step 2500: train loss 1.3928, val loss 1.6263 (eval 4.7s)
# iter 2600, train loss 1.4458
# iter 2700, train loss 1.4720
# iter 2800, train loss 1.4225
# iter 2900, train loss 1.4167
# iter 3000, train loss 1.3918
# step 3000: train loss 1.3532, val loss 1.5888 (eval 4.7s)
# iter 3100, train loss 1.4490
# iter 3200, train loss 1.3515
# iter 3300, train loss 1.3978
# iter 3400, train loss 1.4206
# iter 3500, train loss 1.3754
# step 3500: train loss 1.3137, val loss 1.5712 (eval 4.7s)
# iter 3600, train loss 1.3935
# iter 3700, train loss 1.3858
# iter 3800, train loss 1.3406
# iter 3900, train loss 1.3217
# iter 4000, train loss 1.3112
# step 4000: train loss 1.2897, val loss 1.5603 (eval 4.7s)
# iter 4100, train loss 1.3357
# iter 4200, train loss 1.3363
# iter 4300, train loss 1.3157
# iter 4400, train loss 1.3406
# iter 4500, train loss 1.3351
# step 4500: train loss 1.2638, val loss 1.5513 (eval 4.7s)
# iter 4600, train loss 1.2914
# iter 4700, train loss 1.2931
# iter 4800, train loss 1.3392
# iter 4900, train loss 1.3331
# iter 5000, train loss 1.2988
# step 5000: train loss 1.2456, val loss 1.5566 (eval 4.7s)
# iter 5100, train loss 1.2959
# iter 5200, train loss 1.2592
# iter 5300, train loss 1.2741
# iter 5400, train loss 1.2606
# iter 5500, train loss 1.3017
# step 5500: train loss 1.2217, val loss 1.5519 (eval 4.7s)
# iter 5600, train loss 1.2773
# iter 5700, train loss 1.2694
# iter 5800, train loss 1.3014
# iter 5900, train loss 1.2913
# iter 6000, train loss 1.2888
# step 6000: train loss 1.2076, val loss 1.5443 (eval 4.7s)
# iter 6100, train loss 1.2580
# iter 6200, train loss 1.2453
# iter 6300, train loss 1.2648
# iter 6400, train loss 1.2797
# iter 6500, train loss 1.2253
# step 6500: train loss 1.1864, val loss 1.5408 (eval 4.7s)
# iter 6600, train loss 1.2110
# iter 6700, train loss 1.2235
# iter 6800, train loss 1.2350
# iter 6900, train loss 1.2431
# iter 7000, train loss 1.2481
# step 7000: train loss 1.1587, val loss 1.5484 (eval 4.7s)
# iter 7100, train loss 1.2231
# iter 7200, train loss 1.2262
# iter 7300, train loss 1.1962
# iter 7400, train loss 1.2351
# iter 7500, train loss 1.2260
# step 7500: train loss 1.1377, val loss 1.5602 (eval 4.7s)
# iter 7600, train loss 1.1968
# iter 7700, train loss 1.1927
# iter 7800, train loss 1.1793
# iter 7900, train loss 1.1846
# iter 8000, train loss 1.2210
# step 8000: train loss 1.1244, val loss 1.5607 (eval 4.6s)
# iter 8100, train loss 1.2005
# iter 8200, train loss 1.1508
# iter 8300, train loss 1.1761
# iter 8400, train loss 1.1478
# iter 8500, train loss 1.1882
# step 8500: train loss 1.1067, val loss 1.5624 (eval 4.7s)
# iter 8600, train loss 1.1914
# iter 8700, train loss 1.1833
# iter 8800, train loss 1.1774
# iter 8900, train loss 1.1832
# iter 9000, train loss 1.1535
# step 9000: train loss 1.0813, val loss 1.5712 (eval 4.7s)
# iter 9100, train loss 1.1525
# iter 9200, train loss 1.1733
# iter 9300, train loss 1.1538
# iter 9400, train loss 1.1646
# iter 9500, train loss 1.1611
# step 9500: train loss 1.0656, val loss 1.5884 (eval 4.7s)
# iter 9600, train loss 1.1292
# iter 9700, train loss 1.1362
# iter 9800, train loss 1.1306
# iter 9900, train loss 1.1214
# iter 10000, train loss 1.1402
# step 10000: train loss 1.0478, val loss 1.5871 (eval 4.7s)
# iter 10100, train loss 1.1368
# iter 10200, train loss 1.1341
# iter 10300, train loss 1.1438
# iter 10400, train loss 1.1170
# iter 10500, train loss 1.0951
# step 10500: train loss 1.0330, val loss 1.6185 (eval 4.7s)
# iter 10600, train loss 1.0935
# iter 10700, train loss 1.1007
# iter 10800, train loss 1.0856
# iter 10900, train loss 1.0442
# iter 11000, train loss 1.1255
# step 11000: train loss 1.0090, val loss 1.6175 (eval 4.7s)
# iter 11100, train loss 1.1085
# iter 11200, train loss 1.1126
# iter 11300, train loss 1.0934
# iter 11400, train loss 1.0912
# iter 11500, train loss 1.0833
# step 11500: train loss 0.9975, val loss 1.6425 (eval 4.7s)
# iter 11600, train loss 1.1118
# iter 11700, train loss 1.1100
# iter 11800, train loss 1.0874
# iter 11900, train loss 1.1089
# iter 12000, train loss 1.0812
# step 12000: train loss 0.9765, val loss 1.6557 (eval 4.7s)
# iter 12100, train loss 1.0655
# iter 12200, train loss 1.0783
# iter 12300, train loss 1.0692
# iter 12400, train loss 1.0931
# iter 12500, train loss 1.0830
# step 12500: train loss 0.9522, val loss 1.6680 (eval 4.7s)
# iter 12600, train loss 1.0556
# iter 12700, train loss 1.0874
# iter 12800, train loss 1.0093
# iter 12900, train loss 1.0403
# iter 13000, train loss 1.0260
# step 13000: train loss 0.9361, val loss 1.6837 (eval 4.7s)
# iter 13100, train loss 1.0593
# iter 13200, train loss 1.0110
# iter 13300, train loss 1.0299
# iter 13400, train loss 1.0299
# iter 13500, train loss 1.0265
# step 13500: train loss 0.9162, val loss 1.6813 (eval 4.7s)
# iter 13600, train loss 1.0213
# iter 13700, train loss 1.0148
# iter 13800, train loss 1.0361
# iter 13900, train loss 1.0310
# iter 14000, train loss 1.0161
# step 14000: train loss 0.8987, val loss 1.7046 (eval 4.7s)
# iter 14100, train loss 1.0064
# iter 14200, train loss 0.9998
# iter 14300, train loss 1.0058
# iter 14400, train loss 1.0361
# iter 14500, train loss 1.0090
# step 14500: train loss 0.8793, val loss 1.7259 (eval 4.7s)
# iter 14600, train loss 1.0017
# iter 14700, train loss 0.9905
# iter 14800, train loss 0.9952
# iter 14900, train loss 1.0117
# iter 15000, train loss 1.0144
# step 15000: train loss 0.8621, val loss 1.7400 (eval 4.7s)
# iter 15100, train loss 0.9908
# iter 15200, train loss 0.9752
# iter 15300, train loss 0.9849
# iter 15400, train loss 0.9833
# iter 15500, train loss 0.9500
# step 15500: train loss 0.8472, val loss 1.7535 (eval 4.7s)
# iter 15600, train loss 0.9796
# iter 15700, train loss 0.9650
# iter 15800, train loss 0.9669
# iter 15900, train loss 1.0162
# iter 16000, train loss 0.9702
# step 16000: train loss 0.8334, val loss 1.7862 (eval 4.7s)
# iter 16100, train loss 0.9647
# iter 16200, train loss 0.9914
# iter 16300, train loss 0.9723
# iter 16400, train loss 0.9666
# iter 16500, train loss 0.9738
# step 16500: train loss 0.8102, val loss 1.7916 (eval 4.7s)
# iter 16600, train loss 0.9526
# iter 16700, train loss 0.9651
# iter 16800, train loss 0.9331
# iter 16900, train loss 0.9422
# iter 17000, train loss 0.9473
# step 17000: train loss 0.8003, val loss 1.8197 (eval 4.7s)
# iter 17100, train loss 0.9468
# iter 17200, train loss 0.9584
# iter 17300, train loss 0.9445
# iter 17400, train loss 0.9375
# iter 17500, train loss 0.9351
# step 17500: train loss 0.7822, val loss 1.8237 (eval 4.7s)
# iter 17600, train loss 0.9407
# iter 17700, train loss 0.8907
# iter 17800, train loss 0.9438
# iter 17900, train loss 0.9224
# iter 18000, train loss 0.9312
# step 18000: train loss 0.7617, val loss 1.8366 (eval 4.7s)
# iter 18100, train loss 0.8988
# iter 18200, train loss 0.9525
# iter 18300, train loss 0.8953
# iter 18400, train loss 0.9348
# iter 18500, train loss 0.9288
# step 18500: train loss 0.7537, val loss 1.8527 (eval 4.7s)
# iter 18600, train loss 0.8992
# iter 18700, train loss 0.8956
# iter 18800, train loss 0.8966
# iter 18900, train loss 0.9127
# iter 19000, train loss 0.8776
# step 19000: train loss 0.7325, val loss 1.8920 (eval 4.7s)
# iter 19100, train loss 0.8817
# iter 19200, train loss 0.9037
# iter 19300, train loss 0.9093
# iter 19400, train loss 0.8888
# iter 19500, train loss 0.9018
# step 19500: train loss 0.7228, val loss 1.9047 (eval 4.7s)
# iter 19600, train loss 0.9152
# iter 19700, train loss 0.8593
# iter 19800, train loss 0.8667
# iter 19900, train loss 0.8882
# iter 20000, train loss 0.8873
# Saved model to vanilla_lm.pt
